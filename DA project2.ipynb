# %%
with open("finaldata.txt", encoding = 'utf-8') as f:
    data = f.read()

# %%
chunks = data.split("\n\n") 
chunks = [c for c in chunks if len(c)>3 ]

# %%
def parse_chunk(chunk):
    chunk = chunk.strip()
    sep_chunk = chunk.split('\n')

    username = sep_chunk[0]
    no_of_posts = int(sep_chunk[1].split("post")[0].replace(",", ""))
    no_of_followers = float(sep_chunk[2].split("folower")[0].replace(",","").replace("K","").replace("M","").replace("followers",""))
    if ("K" in sep_chunk[2]):
        no_of_followers = int(no_of_followers*1000)
    elif ("M" in sep_chunk[2]):
        no_of_followers = int(no_of_followers*1000000)
    else:
        no_of_followers = int(no_of_followers)

    no_of_following = float(sep_chunk[3].split("following")[0].replace(",","").replace("K","").replace("M",""))
    if ("K" in sep_chunk[3]):
        no_of_following = int(no_of_following*1000)
    elif ("M" in sep_chunk[3]):
        no_of_following = int(no_of_following*1000000)
    else:
        no_of_following = int(no_of_following)
    name = sep_chunk[4]
    if len(sep_chunk) > 5:
        type_of_page = sep_chunk[5]
        bio = "\n".join(sep_chunk[6:])
    else:
        type_of_page = "unknown"
        bio = ""

    return {
        "Username": username,
        "Total posts": no_of_posts,
        "Followers": no_of_followers,
        "Total following": no_of_following,
        "Name": name,
        "Type of page": type_of_page,
        "Bio": bio
    }

# %%
all_chunks = []

for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)

# %%
import json
s = json.dumps(all_chunks, indent = 4)
with open ("data.json","w") as f:
    f.write(s)

# %% [markdown]
# # who has maximum posts?

# %%
max = 0
for chunk in all_chunks:
    if (max<chunk['Total posts']):
        max = chunk['Total posts']
        chunk_with_max_post = chunk
print("Page with MAXIMUM POSTS : ",chunk_with_max_post['Username'])
# Out:
# Page with MAXIMUM POSTS :  startuphub_blr

# %% [markdown]
# # who has maximum follower

# %%
max = 0
for chunk in all_chunks:
    if (max<chunk['Followers']):
        max = chunk['Followers']
        chunk_with_max_followers = chunk
print("Page with MAXIMUM FOLLOWERS : ",chunk_with_max_followers['Username'])
# Out:
# Page with MAXIMUM FOLLOWERS :  _anujsinghal

# %%
max = 0
for chunk in all_chunks:
    if (max<chunk['Total following']):
        max = chunk['Total following']
        chunk_with_max_followings = chunk
print("Page with MAXIMUM FOLLOWINGS : ",chunk_with_max_followings['Username'])
# Out:
# Page with MAXIMUM FOLLOWINGS :  bangalore_tech_bro

# %%
categories = []

for chunk in all_chunks:
    categories.append(chunk['Type of page'])
print("Total categories : ",len(categories))
# Out:
# Total categories :  107
